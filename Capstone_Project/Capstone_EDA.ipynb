# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
df = pd.read_csv('spinal_data.csv')

# %%
df.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope    status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   pelvic_slope              310 non-null    float64
#  7   direct_tilt               310 non-null    float64
#  8   thoracic_slope            310 non-null    float64
#  9   cervical_tilt             310 non-null    float64
#  10  sacrum_angle              310 non-null    float64
#  11  scoliosis_slope           310 non-null    float64
#  12  status                    310 non-null    object
# dtypes: float64(12), object(1)
# ...

# %%
df.shape
# Out:
# (310, 13)

# %%
# Describe columns

# %%
df.describe().T
# Out:
#                           count        mean        std        min         25%  \
# pelvic_incidence          310.0   60.496653  17.236520  26.147921   46.430294
# pelvic_tilt               310.0   17.542822  10.008330  -6.554948   10.667069
# lumbar_lordosis_angle     310.0   51.930930  18.554064  14.000000   37.000000
# sacral_slope              310.0   42.953831  13.423102  13.366931   33.347122
# pelvic_radius             310.0  117.920655  13.317377  70.082575  110.709196
# degree_spondylolisthesis  310.0   26.296694  37.559027 -11.058179    1.603727
# pelvic_slope              310.0    0.472979   0.285787   0.003220    0.224367
# direct_tilt               310.0   21.321526   8.639423   7.027000   13.054400
# thoracic_slope            310.0   13.064511   3.399713   7.037800   10.417800
# cervical_tilt             310.0   11.933317   2.893265   7.030600    9.541140
# sacrum_angle              310.0  -14.053139  12.225582 -35.287375  -24.289522
# ...

# %%
# Check what status values there are
df.status.unique()
# Out:
# array(['Abnormal', 'Normal'], dtype=object)

# %%
df.isnull().sum(axis = 0)
# Out:
# pelvic_incidence            0
# pelvic_tilt                 0
# lumbar_lordosis_angle       0
# sacral_slope                0
# pelvic_radius               0
# degree_spondylolisthesis    0
# pelvic_slope                0
# direct_tilt                 0
# thoracic_slope              0
# cervical_tilt               0
# sacrum_angle                0
# scoliosis_slope             0
# status                      0
# dtype: int64

# %%
# Check value count of status
df.status.value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: status, dtype: int64

# %%
fig, axes = plt.subplots(3, 4, figsize = (15,20))
axes = axes.flatten()
for i in range(0,len(df.columns)-1):
   
    sns.kdeplot(df.iloc[:,i], ax=axes[i],shade=True, color="r")

plt.tight_layout()
plt.show()

# %% [markdown]
# Most are normally distributed.
# Degree spondylolisthesis has a left skew

# %%
# Plot status count
df.value_counts(df['status']).plot.bar()
# Out:
# <AxesSubplot:xlabel='status'>

# %% [markdown]
# There is a class imbalance that will need to be weighted accordingly during modelling

# %%
# Check heatmap correlation
plt.subplots(figsize=(12,8))
sns.heatmap(df.corr(), cmap='YlGnBu',annot=True)
# Out:
# <AxesSubplot:>

# %%
# Check heatmap correlation
sns.set_theme(style="white")

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Assess values of each spinal parameter between normal and abnormal states

sns.set(style="darkgrid")
fig,ax=plt.subplots(2,3,figsize=(15,8))
sns.violinplot("status","pelvic_incidence",data=df,ax=ax[0,0])
sns.violinplot("status","pelvic_tilt",data=df,ax=ax[0,1])
sns.violinplot("status","sacral_slope",data=df,ax=ax[0,2])
sns.violinplot("status","degree_spondylolisthesis",data=df,ax=ax[1,0])
sns.violinplot("status","lumbar_lordosis_angle",data=df,ax=ax[1,1])
sns.violinplot("status","pelvic_radius",data=df,ax=ax[1,2])
plt.show()
# Out:
# C:\Users\Peter Le\anaconda3\envs\Python 38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Peter Le\anaconda3\envs\Python 38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
